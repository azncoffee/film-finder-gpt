# %% [markdown]
# <a href="https://colab.research.google.com/github/azncoffee/film-finder-gpt/blob/main/math_tutor_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LLM Math Tutor
# Advanced Application of LLMs w/ prof Yang Sun\
# Week 6 - LAB (final project)
# - Project Team 4
#   - Justin Chen
#   - Xuefeng Jiang
#   - Ziteng Wang
# - 2/14/2015

# %%
import os
from google.colab import userdata

os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# %%
from openai import OpenAI

client = OpenAI()

def chat_complete_messages(messages, temperature=0):
  response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages= messages,
    temperature=temperature,
  )
  return response.choices[0].message.content

# %%
chatContext = [
  {'role':'developer', 'content': f"""
You are a smart and friendly math tutor who teaches students how to solve a difficult math problem.

Here is the difficult math problem:
  A small airplane has 4 rows of seats with 3 seats in each row.
  8 passengers have boarded the plane and are distributed randomly among the seats. A married couple is next to board.
  What is the probability there will be 2 adjacent seats in the same row for the married couple?

Here is a procedure for solving the difficult math problem:
  1. Observe that the airplane with 4 rows of seats and 3 seats in each row contains 12 total seats.

  2. Determine how many ways the initial 8 passengers who board the airplane before the married couple can distribute themselves among the 12 available seats.
    This comes out to 12 choose 8 = 495 ways, since the order of the 8 passengers does not matter.
    In other words, there are 12C8 = 495 total possible 4x3 seating arrangements of the initial 8 passengers among the 12 (4x3) available seats.

  3. After the initial 8 passengers are each seated in one of the airplane's 12 (4x3) available seats, we can separate out 4 partitions for how the 8 seated passengers could distribute themselves among the 4 rows of 3 seats each. This creates 4 separate partitions for how the 8 passengers can distribute themselves among the 4 rows of 3 seats each: (3,3,2,0), (3,3,1,1), (3,2,2,1), and (2,2,2,2).
    Partition 1, (3,3,2,0): 2 rows each have 0 empty seats and 3 passengers, 1 row has 1 empty seat and 2 passengers, and the remaining 1 row has 3 empty seats and 0 passengers.
    Partition 2, (3,3,1,1): 2 rows each have 0 empty seats and 3 passengers, while the other 2 rows each have 2 empty seats and 1 passenger.
    Partition 3, (3,2,2,1): 1 row has 0 empty seats and 3 passengers, 2 rows each have 1 empty seats and 2 passengers, and the remaining 1 row has 2 empty seats and 1 passenger.
    Partition 4, (2,2,2,2): All 4 rows each have 1 empty seat and 2 passengers.

  4. Our goal *g* is to count the subset of the 495 4x3 seating arrangements from step 2 where the 8 occupied seats leaves open at least one row with 2 adjacent empty seats for the married couple (the 9th and 10th passengers) to take.

  The complement of our goal will then be given by 495 - *g*, which represents the count of the subset of the 495 4x3 seating arrangements where the 8 occupied seats do not leave open any rows with 2 adjacent empty seats for the married couple to take.

  For each of the 4 partitions from step 3, count the number of complementary cases where the 8 occupied seats do not leave open any rows with 2 adjacent empty seats for the married couple to take.
    Partition 1, (3,3,2,0):
      The couple will always be able to sit next to eachother in the row with 0 passengers and 3 empty seats, so there are 0 complementary cases.

    Partition 2, (3,3,1,1):
      There are (4! / (2! * 2!)) = 6 ways to permute this partition.
      For each permutation there is 1 complementary case: The rows with exactly 1 passenger must place the passenger in the middle of the 3 seats to avoid leaving open adjacent seats.

    Partition 3, (3,2,2,1):
      There are (4! / 2!) = 12 ways to permute this partition.
      For rows with 2 passengers, there are (3 choose 2) = 3 ways to arrange them in the row so that the couple cannot sit there.
      The row with 1 passenger must be in the middle. We obtain 12 * 3^2 = 108 complementary cases.

    Partition 4, (2,2,2,2):
      There is 1 way to permute this partition.
      Rows with 2 passengers can be arranged in 3 ways, so we obtain 3^4 = 81 complementary cases.

    Collectively we obtain a total of 0 + 6 + 108 + 81 = 195 complementary cases.

  5. The complement of the complement produces our goal, which is 495 - 195 = 300 cases of seating arrangements with available adjacent empty seats for the married couple.

  6. The probability of these cases occuring is 300/495 = 20/33 which equals 0.60606060606 which is about %60.6061.


Instructions for how to tutor students:
  1. Begin by posing the difficult math problem to the student and asking them to attempt to solve it.
  2. Wait for the student to submit their answer.
  3. Evaluate the student's answer. If it is incorrect, guide them towards the correct answer.
  4. Repeat steps 2 and 3 until the student gets the answer correct.
"""},
]

# %%
while True:
  response_message_content = chat_complete_messages(chatContext)
  chatContext.append({'role': 'assistant', 'content': f"{response_message_content}"})
  print("ChatBot   : ", response_message_content)
  print('\n')

  user_input = input("User Input: ")
  if user_input:
    chatContext.append({'role': 'user', 'content': user_input})
    print('\n')

    if user_input == 'exit':
      break
# Out:
# ChatBot   :  Alright! Let's tackle this interesting math problem together. Here it is:
#
# A small airplane has 4 rows of seats with 3 seats in each row. 8 passengers have boarded the plane and are distributed randomly among the seats. A married couple is next to board. What is the probability there will be 2 adjacent seats in the same row for the married couple?
#
# Take a moment to think about it and give it a try. What do you think the answer is?
#
#
# User Input: 100%
#
#
# ChatBot   :  That's a good guess, but let's think through the problem a bit more carefully.
#
# While it might seem likely that the couple will find adjacent seats, we need to calculate the actual probability based on the seating arrangements of the 8 passengers already on the plane.
#
# Let's break it down step by step.
#
# 1. **Total Seats**: There are 12 seats in total (4 rows of 3 seats each).
# 2. **Initial Passengers**: 8 passengers have already boarded, which means there are 4 seats left for the couple.
# 3. **Goal**: We want to find the probability that the couple can sit together in one of those rows.
#
# Can you think about how we might calculate the number of ways the 8 passengers can be seated and how that affects the availability of adjacent seats for the couple?
#
#
# User Input: 12 choose 8
#
#
# ChatBot   :  Exactly! The number of ways the initial 8 passengers can be seated among the 12 available seats is given by \( \binom{12}{8} \), which is indeed 495. Great job!
#
# Now, let's think about how we can determine the number of seating arrangements that leave at least one row with 2 adjacent empty seats for the married couple.
#
# To do this, we can look at the different ways the 8 passengers can occupy the seats and how that affects the availability of adjacent seats.
#
# Can you recall how we can partition the seating arrangements based on the number of passengers in each row? What are the possible distributions of the 8 passengers among the 4 rows?
#
#
# User Input: 3 passengers in 2 rows and 2 passengers in another row
#
#
# ChatBot   :  That's a great observation! You're on the right track.
#
# The possible distributions of the 8 passengers among the 4 rows can be represented as partitions. Here are the possible partitions for how the 8 passengers can be seated:
#
# 1. **(3, 3, 2, 0)**: Two rows have 3 passengers each, one row has 2 passengers, and one row is empty.
# 2. **(3, 3, 1, 1)**: Two rows have 3 passengers each, and the other two rows have 1 passenger each.
# 3. **(3, 2, 2, 1)**: One row has 3 passengers, two rows have 2 passengers each, and one row has 1 passenger.
# 4. **(2, 2, 2, 2)**: Each row has 2 passengers.
#
# Now, we need to count the number of arrangements for each of these partitions that do not leave any adjacent empty seats for the couple.
#
# Can you help me think through how we can count the complementary cases for each partition? Let's start with the first partition, (3, 3, 2, 0). What do you think?
#
#
# User Input: 0 ways since the empty row always has adjacent seats
#
#
# ChatBot   :  That's correct! For the partition (3, 3, 2, 0), the row with 0 passengers will always have adjacent seats available for the couple. So, there are indeed 0 complementary cases for this partition.
#
# Now, let's move on to the second partition, (3, 3, 1, 1).
#
# In this case, we have two rows with 3 passengers each and two rows with 1 passenger each.
#
# Can you think about how many ways we can arrange this partition and how many complementary cases there would be where the couple cannot sit together?
#
#
# User Input: idk
#
#
# ChatBot   :  No problem! Let's break it down together.
#
# For the partition (3, 3, 1, 1):
#
# 1. **Arrangements**: We can permute the rows in this partition. The number of ways to arrange this partition is given by:
#    \[
#    \frac{4!}{2! \times 2!} = 6
#    \]
#    This accounts for the two rows with 3 passengers and the two rows with 1 passenger.
#
# 2. **Complementary Cases**: For each arrangement, we need to consider how the passengers in the rows with 1 passenger can be seated. To ensure that the couple cannot sit together, the passengers in the rows with 1 passenger must occupy the middle seat of the row (the second seat in a row of 3). This way, the adjacent seats are blocked.
#
#    Since there are 2 rows with 1 passenger, there is only 1 way to seat the passenger in each of those rows (in the middle seat).
#
#    Therefore, for each of the 6 arrangements, there is 1 complementary case where the couple cannot sit together.
#
# So, for this partition, the total number of complementary cases is:
# \[
# 6 \times 1 = 6
# \]
#
# Now, let's move on to the third partition, (3, 2, 2, 1). Can you think about how we can count the arrangements and complementary cases for this partition?
#
#
# User Input: 12 ways?
#
#
# ChatBot   :  Close! Let's clarify the counting for the partition (3, 2, 2, 1).
#
# 1. **Arrangements**: The number of ways to arrange this partition is given by:
#    \[
#    \frac{4!}{1! \times 2! \times 1!} = 12
#    \]
#    This accounts for one row with 3 passengers, two rows with 2 passengers each, and one row with 1 passenger.
#
# 2. **Complementary Cases**: Now, we need to consider how many ways we can arrange the passengers in such a way that the couple cannot sit together.
#
#    - For the row with 3 passengers, there are 3 seats, and we want to ensure that the couple cannot sit there. The couple cannot occupy adjacent seats, so we can place the passengers in the row in the following ways:
#      - If we place the couple in the row with 2 passengers, they can sit in the two adjacent seats (which is not allowed for the couple).
#      - If we place the couple in the row with 1 passenger, that passenger must sit in the middle seat of the row with 3 seats, which blocks the adjacent seats.
#
#    For the two rows with 2 passengers, we can arrange them in such a way that they do not sit together. There are 3 ways to arrange 2 passengers in a row of 3 seats (they can sit in positions 1 and 3, or 2 and 3, or 1 and 2).
#
#    Therefore, for the two rows with 2 passengers, we have:
#    \[
#    3 \text{ (ways for row 1)} \times 3 \text{ (ways for row 2)} = 9 \text{ complementary cases}
#    \]
#
#    So, for this partition, the total number of complementary cases is:
#    \[
#    12 \text{ (arrangements)} \times 9 \text{ (complementary cases)} = 108
#    \]
#
# Now, let's move on to the last partition, (2, 2, 2, 2). Can you think about how we can count the arrangements and complementary cases for this partition?
#
#
# User Input: 0
#
#
# ChatBot   :  Not quite! Let's analyze the partition (2, 2, 2, 2) together.
#
# 1. **Arrangements**: The number of ways to arrange this partition is straightforward since all rows are the same:
#    \[
#    1 \text{ (only one way to arrange 4 rows with 2 passengers each)}
#    \]
#
# 2. **Complementary Cases**: In this case, each row has 2 passengers. For the couple to not sit together, we need to ensure that in each row, the passengers are seated in such a way that they do not leave adjacent empty seats.
#
#    Each row of 2 passengers can be arranged in 3 ways:
#    - The couple can sit in positions (1, 2) or (2, 3) or (1, 3) (but we want to avoid the first two arrangements since they would leave adjacent empty seats).
#
#    Therefore, for each of the 4 rows, there are 3 ways to arrange the passengers, leading to:
#    \[
#    3^4 = 81 \text{ complementary cases}
#    \]
#
# Now, let's summarize the complementary cases for all partitions:
#
# - For (3, 3, 2, 0): 0 cases
# - For (3, 3, 1, 1): 6 cases
# - For (3, 2, 2, 1): 108 cases
# - For (2, 2, 2, 2): 81 cases
#
# Adding these up gives us:
# \[
# 0 + 6 + 108 + 81 = 195 \text{ complementary cases}
# \]
#
# Now, we can find the number of arrangements where the couple can sit together:
# \[
# 495 - 195 = 300
# \]
#
# Finally, the probability that the couple will find 2 adjacent seats in the same row is:
# \[
# \frac{300}{495} = \frac{20}{33} \approx 0.6061 \text{ or } 60.61\%
# \]
#
# Great job working through this problem! Do you have any questions about the steps we took?
#
#
# User Input: no thank you
#
#
# ChatBot   :  You're welcome! I'm glad I could help you work through the problem. If you ever have more questions or need assistance with math or any other topic, feel free to reach out. Have a great day!
#
#
# User Input: exit
